# %%
import pandas as pd
import os

# %%
aa=pd.read_csv(r"C:\Users\Siddharth\Desktop\certificates\internshiptask\mini-project\Data-Science-Intern-2-Mini-Project-Task-master\Task 1 Data set\cleaned_data.csv")
credit_card = pd.DataFrame(aa)
#print(credit_card.head())
credit_card.shape

# %%
#print(credit_card["PAY_AMT4"],credit_card["PAY_AMT3"])
credit_card.head()
len(credit_card)
print(credit_card.LIMIT_BAL.max())
credit_card.LIMIT_BAL.min()
credit_card['PAY_1'].value_counts()
# Out:
# 800000
#  0    13087
# -1     5047
#  1     3261
# -2     2476
#  2     2378
#  3      292
#  4       63
#  5       23
#  8       17
#  6       11
#  7        9
# Name: PAY_1, dtype: int64

# %%
credit_card.info
credit_card.columns
credit_card.shape[0] == credit_card['ID'].nunique()
# Out:
# True

# %%
import matplotlib.pyplot as plt #import plotting package

#render plotting automatically
# %matplotlib inline

import matplotlib as mpl #additional plotting functionality

mpl.rcParams['figure.dpi'] = 200

# %%
mpl.rcParams['figure.dpi'] = 150
mpl.rcParams['font.size'] = 8
credit_card[['LIMIT_BAL', 'AGE']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CB15C96808>,
# ...
#       dtype=object)
